# %%
FEATURE_PER_DAY = 18
WINDOW_SIZE = 9
FEATURE_NUM = 9

# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import random

df = pd.read_csv("competitions/ml-2018spring-hw1/train.csv", encoding="big5")

for row in np.arange(10, len(df), FEATURE_PER_DAY):
    df.iloc[row, 3:] = pd.to_numeric(df.iloc[row, 3:], errors="coerce")

df.fillna(0, inplace=True)

# %%
x_data = []
y_data = []

for i in np.arange(0, len(df), FEATURE_PER_DAY):
    arr = np.array(df.iloc[i+9, 3:3+WINDOW_SIZE], dtype=float)
    arr = np.insert(arr, 0, 1) # x0 for bias
    x_data.append(arr)
    y_data.append(np.array(df.iloc[i+9, 3+WINDOW_SIZE+1], dtype=float))

# %%
# Step 1: Model
# Loss function L(f) = sum of (y - f)^2
theta = np.array([0.0] * (FEATURE_NUM + 1)) # all parameters init to 1
# for i in range(len(theta)):
#     theta[i] = random.randint(0, 99)
lr = 0.001
iteration = 30000

lr_ada = np.zeros(FEATURE_NUM + 1)

# %%
theta = np.load('theta_9f.npy')

# %%
from tqdm import tqdm

for i in tqdm(range(iteration)):
    grad = np.zeros(FEATURE_NUM + 1)
    
    for n in range(len(x_data)):
        dot = np.dot(theta, x_data[n])
        for f in range(len(grad)):
            grad[f] = grad[f] - 2.0 * (y_data[n] - dot) * x_data[n][f]
    
    for f in range(len(grad)):
        lr_ada[f] = lr_ada[f] + grad[f] ** 2

    for index in range(len(theta)):
        theta[index] = theta[index] - lr / np.sqrt(lr_ada[index]) * grad[index]
# Out:
# 100%|██████████| 30000/30000 [03:04<00:00, 162.80it/s]

# %%
print(grad)
# Out:
# [ 7.39634253e-07  1.95146602e-05 -6.95414345e-05  4.93219831e-05
#   4.48247197e-05 -1.04283691e-04  6.96620607e-05  1.06124976e-04
#  -1.80331379e-04  6.38902664e-05]

# %%
def computeCost(x_data, y_data, theta):
    cost = 0.0
    for i in range(len(x_data)):
        cost += (np.dot(theta, x_data[i]) - y_data[i]) ** 2
    return cost

# %%
record = [16895.726658446325]

# %%
record.append(computeCost(x_data, y_data, theta))
print(record)
# Out:
# [16895.726658446325, 34967.91013163201, 34967.91013162717]

# %%
for i in range(len(x_data)):
    print(np.dot(theta, x_data[i]), y_data[i])
# Out:
# 54.90891454245442 67.0
# 17.61698743737061 37.0
# 41.43331829497353 19.0
# 33.25635686264211 43.0
# 66.75687088486215 79.0
# 63.27343151005092 83.0
# 38.45525317012198 55.0
# 62.444651255136165 68.0
# 22.705657357745366 23.0
# 17.282280847536693 13.0
# 32.98494598884705 43.0
# 36.645853497631485 41.0
# 18.738856478886575 21.0
# 26.223236432636632 0.0
# 18.591607761999573 16.0
# 26.103883709019932 31.0
# 29.282328412481466 44.0
# 19.60266134410486 21.0
# 72.87975555896561 78.0
# 51.299781858386694 51.0
# 41.134385814733555 49.0
# 26.220340097613352 24.0
# 32.307377194690616 36.0
# 25.105081487946368 7.0
# 10.313083999175863 15.0
# 19.304614170958914 14.0
# 27.07344833845484 28.0
# 18.26748227288754 12.0
# 6.0139949267577855 5.0
# 8.776252265782436 3.0
# 9.375061677155893 21.0
# 18.238082447525173 12.0
# 9.94999950107866 7.0
# 17.14201621821234 20.0
# 11.54172565013855 14.0
# 24.962412862023854 41.0
# 32.840944758086835 49.0
# 47.09187977104369 41.0
# 32.791147409879855 15.0
# 20.210697056314515 14.0
# 19.622550458051066 14.0
# 15.7863381907831 17.0
# 6.929914290428835 0.0
# 36.84694911788901 35.0
# 39.352840983879744 42.0
# 34.03387484940848 50.0
# 40.50749810188764 43.0
# 37.55166542923772 38.0
# 20.74906022163591 26.0
# 30.36570814955655 35.0
# 50.7755016282956 52.0
# 32.99591742137865 32.0
# 13.332293732308417 17.0
# 26.19693437416964 41.0
# 29.97881062385855 28.0
# 14.721835939947749 27.0
# 21.59175370478615 24.0
# 41.31763988074107 59.0
# 24.25538612647127 0.0
# 19.556632481450997 31.0
# 38.85814027574785 58.0
# 17.89773595917944 29.0
# 64.29811891579327 81.0
# 41.08793365840117 44.0
# 37.5534642666361 34.0
# 20.37312255696768 25.0
# 27.512210106041934 24.0
# 13.901481015862466 11.0
# 26.519190999663692 24.0
# 33.80684455371544 39.0
# 25.23591759566125 34.0
# 44.302448919760295 42.0
# 25.4074529185073 14.0
# 13.852188400078191 15.0
# 21.363907438313106 20.0
# 22.980171437575017 25.0
# 37.692944022167225 32.0
# 50.2854120781282 0.0
# 59.54242721188542 -3.0
# 42.581289609445506 51.0
# 38.008035948602725 40.0
# 40.52064629781877 52.0
# 45.51994913234452 55.0
# 90.55065610221965 90.0
# 42.769039128692285 45.0
# 22.282587822759954 22.0
# 22.46324117798597 25.0
# 36.609747181313956 38.0
# 52.915265328304514 34.0
# 37.33171898503618 54.0
# 46.69461509257839 60.0
# 25.161509453619338 20.0
# 18.33271940375465 24.0
# 35.7174173462969 40.0
# 22.937293030146236 24.0
# 41.983212896284066 36.0
# 23.501648866432973 30.0
# 23.808457793550865 19.0
# 15.811202502540189 18.0
# 15.622902578690903 6.0
# 27.98148874565853 25.0
# 26.973445731494635 41.0
# 40.29572515065802 36.0
# 14.116158399586515 6.0
# 27.59133817538928 35.0
# 27.11290790194384 43.0
# 10.21133382658659 2.0
# 14.908852944317752 28.0
# 41.42570190444631 21.0
# 5.956896231054246 -3.0
# 20.46336579227551 17.0
# 15.176325490226851 0.0
# 67.47991083435984 0.0
# 15.343387507822833 13.0
# 13.661074366532972 3.0
# 34.34699090293182 0.0
# 41.751760874108086 54.0
# 74.38433953482198 75.0
# 32.45979807600857 22.0
# 32.99457122935459 33.0
# 35.81190723276923 41.0
# 63.745543239929816 74.0
# 20.440361049606192 24.0

# %%
np.save('theta_9f', theta)

# %%
dt = pd.read_csv("competitions/ml-2018spring-hw1/test.csv", header=None, encoding="big5")

for row in np.arange(10, len(dt), FEATURE_PER_DAY):
    dt.iloc[row, 2:] = pd.to_numeric(dt.iloc[row, 2:], errors="coerce")
    
dt.fillna(0, inplace=True)

# %%
x_test = []
y_test = []

for i in np.arange(8, len(dt), FEATURE_PER_DAY):
    arr = np.array(dt.iloc[i, 2:2+WINDOW_SIZE], dtype=float)
    arr = np.insert(arr, 0, 1) # x0 for bias
    x_test.append(arr)
    
for i in range(len(x_test)):
    y_test.append(np.dot(theta, x_test[i]))

# %%
for i in range(len(y_test)):
    if (y_test[i] < 0):
        y_test[i] = 0

# %%
arr = [["id_" + str(i), y_test[i]] for i in range(len(y_test))]
dw = pd.DataFrame(arr, columns = ["id", "value"])
dw.to_csv("output_9f.csv", index=False)
